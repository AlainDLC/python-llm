# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)

# %%
agent = Agent(name="MotorbikeGuro",instructions="You are an Kawasaki ninja driver thats TELLS JOKES about other Brands ", model="gpt-4o-mini")

# %%
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about  other Brands like Harley davidson")
    print(result.final_output)
